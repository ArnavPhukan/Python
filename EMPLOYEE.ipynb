# %%
import pickle
import sys

# %%
#created parent class
class Employee(object):
    
    #passing the values of the columns emp_name,emp_city and emp_department 
    def __init__(self,emp_name,emp_city):
        
    #encapsulating emp_name and emp_department 
        self.__employee_name=emp_name  
        self.employee_city=emp_city
        self.__department = dept #Aggregation
        
    #defining the get methods for the attributes    
    def get_name(self):
        return self.__employee_name
    def get_city(self):
        return self.employee_city
    def get_department_data(self):
        return self.__department
    
    #defining the set methods for the attributes
    def set_name(self,emp_name):
        self.__employee_name=emp_name
    def set_city(self,emp_city):
        self.employee_city=emp_city
    def set_department_data(self, dept):
        self.__department = dept
        
    #representing the class objects in the form of string
    
    def __str__(self):
        emp="Employee Name: {self.__employee_name}"
        emp+="Employee City: {self.employee_city}"
        emp += f"\n\n***Department Data***\n{self.__department.__str__()}"
        return emp

# %%
#creating subclass 1: FulltimeEmployee
class FullTimeEmployee(Employee):
    def __init__(self,emp_name,emp_city,dept,salary):
        super().__init__(emp_name,emp_city,dept)
        self.__emp__salary=emp_salary
        
    def get_salary(self):
        return self.__emp_salary
        
    def set_salary(self,emp_salary):
        self.__emp_salary
            
    def calculatesalary(self):
        #condition 1 is for less than 37000
        if(self.__emp_salary)<=37000:
            #tax rate of 1.8%
            tax=0.18*self__emp_salary
            total_tax=self.__emp_slary-tax
            return total_tax
        #condition 2 in between 37000 and 75000
        elif(self.__emp_salary>37000 and self.__emp_salary<75000):
            #successive tax rate of 1.8% and 2.8%
            tax=(0.18*37000)+(0.28*(self.__emp_salary-37000))
            total_tax=self.__emp_salary-tax
            return total_tax
        #condition 3 is more than 75000
        else:
            #three successive tax rates at 1.8%,2.8% and 3.2%
            tax=((0.18*37000)+(0.28*(75000-37000))+(0.32*(self.__emp_salary-75000)))
            total_tax=self.__emp_salary-tax
            return total_tax
    #displaying in the form of string objects    
    def __str__(self):
        #inheriting the employee details to subclass 1
        cd=super().__str__()
        cd+="\nEmployee Details\n{cd}"
        cd+="\t Full Time Employee\t"
        cd+="\f Salary: {self.__emp_salary}"
        return cd

# %%
#creating subclass 2: ContractBasis
class ContractBasis(Employee):
    def __init__(self, emp_name, emp_address,dept,hoursWorked, hourlyRate):
        super().__init__(emp_name, emp_address,dept)
        self.__emp_hoursWorked = hoursWorked
        self.__emp_hourlyRate = hourlyRate

    def get_hoursWorked(self):
        return self.__emp_hoursWorked

    def set_hoursWorked(self, hoursWorked):
        self.__emp_hoursWorked = hoursWorked
        
    def get_hourlyRate(self):
        return self.__emp_hourlyRate

    def set_hourlyRate(self, hourlyRate):
        self.__emp_hourlyRate = hourlyRate

    def calculatesalary(self):
        if(self.__emp_hoursWorked <= 40):
            #no tax below 40 hours of work
            total_tax=self.__emp_hourlyRate * self.__emp_hoursWorked
            return total_tax
        else:
            #tax rate at 1.8%
            total_tax=((self.__emp_hourlyRate * 40) + (self.__emp_hourlyRate * (self.__emp_hoursWorked - 40) * 1.8))
            return total_tax

    def __str__(self):
        cd = super().__str__()
        cd = f"\n\n***Employee Details***\n{cd}"
        cd += f"\n\n***Hourly Rate Employee***"
        cd += f"\nHours Worked: {self.__emp_hoursWorked}"
        cd += f"\nHourly Rate: {self.__emp_hourlyRate}"
        return cd

# %%
#creating subclass 3 : Consultant
class Consultant(Employee): 
    
    def __init__(self, emp_name, emp_address,dept, hoursWorked, ProjectType):
        super().__init__(emp_name, emp_address,dept)
        self.__emp_hoursWorked = hoursWorked
        self.__emp_proj_type = ProjectType

    def get_hoursWorked(self):
        return self.__emp_hoursWorked

    def set_hoursWorked(self, hoursWorked):
        self.__emp_hoursWorked = hoursWorked
        
    def get_ProjectType(self):
        return self.__emp_proj_type

    def set_ProjectType(self, hourlyRate):
        self.__emp_proj_type = ProjectType

    def calculatesalary(self):
        if(self.__emp_proj_type == 1):
            return (55.0 * self.__emp_hoursWorked)
        elif(self.__emp_proj_type == 2):
            return (70.0 * self.__emp_hoursWorked)
        else:
            return (85.0 * self.__emp_hoursWorked)

    def __str__(self):
        cd= super().__str__()
        cd = f"\n\n***Employee Details***\n{cd}"
        cd += f"\n\n***Consultant***"
        cd += f"\nProject Type: {self.__emp_proj_type}"
        cd += f"\nHours Worked: {self.__emp_hoursWorked}"
        return cd

# %%
class Department:
    def __init__(self,name,number,location):
        self.__dept_name = name
        self.__dept_number = number
        self.dept_location = location

    def get_name(self):
        return self.__dept_name

    def get_number(self):
        return self.__dept_number

    def get_location(self):
        return self.__dept_location

    def set_name(self, dept_name):
        self.__dept_name = name

    def set_number(self, dept_number):
        self.__dept_number = number

    def set_loaction(self,location):
        self.__dept_loaction = location

    def __str__(self):
        dept = f"Department Name: {self.__dept_name}"
        dept += f"\Department Number: {self.__dept_number}"
        dept += f"\nDepartment Location: {self.__dept_location}"
        return dept

# %%
#Define the main() method.  This just calls the menu() method

def main():
    menu()

# %%
def menu():
    emp_data_list = read_file()
    choice = 1

    while choice >=  1 and choice <= 5:
        print("\n****====MENU OPTIONS====*****")
        print("1. Add New Employees. ")
        print("2. Display Employee Details present in the system. ")
        print("3. List the employee salary details. ")
        print("4. Display the employee name together with department details. ")
        print("5. Exit the system.")

        try:
            choice = int(input("Your choice action: "))
            if(choice < 1 or choice > 5):
                raise ValueError                 
        except ValueError:
            print('You must enter an integer between 1 and 5!')
            print('Try again!!!')
            choice = 1
            continue

        if choice == 1:
            emp_data_list.append(run_option1())
        elif choice == 2:
            if(len(emp_data_list) == 0):
                print("No employees in database!")
            else:
                run_option2(emp_data_list) 
        elif choice == 3:
            if(len(emp_data_list) == 0):
                print("No employees in database!")
            else:
                run_option3() 
        elif choice == 4:
            if(len(emp_data_list) == 0):
                print("No employees in database!")
            else:
                run_option4() 
        elif choice == 5:
            run_option5(emp_data_list)

# %%
def read_file():
    lst=[] #create a empty list
    try:
        f=open("EMPDATA.txt",'r')
    except FileNotFoundError:
        return lst
    else:
        try:
            sel=1
            while(sel):
                lst.append(f)
        except EOFError: 
            f.close()
            return lst

# %%
def run_option1():
    ch = 0
   
    while(ch < 1 or ch > 3): #Repeat the prompt until the user enters an valid value of 1, 2, or 3
        try:
            ch = int(input("Type of Employee?(1-Full Time Employee; 2-Contract Basis; 3-Consultant) : "))
        except ValueError: 
            print('Wrong chection of type of employee!')
            continue

    emp_name, emp_city = get_emp_input()

    dept_name, dept_number, location = get_department_input()
    dept_obj = Department(dept_name,dept_number,location) 

    if ch == 1:
        sal = get_fulltimeemployee_input()
        result = FullTimeEmployee(emp_name, emp_city, dept_obj, sal)
    elif ch == 2:
        hoursWorked, hourlyRate = get_contractbasis_input()
        result = ContractBais(emp_name, emp_city, dept_obj, hoursWorked, hourlyRate)
    elif ch == 3:
        hoursWorked, ProjectType = get_consultant_input()
        result = Consultant(emp_name, emp_city, dept_obj, hoursWorked, ProjectType)
    return result

# %%
def run_option2(my_lst):
    print("************************************")
    for i in lst:
        print(i)
        print("********************************")

# %%
def run_option3():
    f = read_file()
        
    if(len(f) != 0):
        print("-----------------------------")
        for _ in f:
            print("Employee Name: ", _.get_name())
            print("Employee Salary: ",_.calculatesalary())
            print("-----------------------------")
    else:
        print("File empty!")
        menu()

# %%
def run_option4():
    f = read_file()
        
    if(len(f) != 0):
        print("-----------------------------")
        for _ in f:
            if(str(_.get_department_data().get_department_name())== "Sales"):
                print("Employee Name: ", _.get_name())
                print(_.get_department_data())
                print("-----------------------------")
    else:
        print("File empty!")
        menu()

# %%
def run_option5(my_lst):
    #The program first confirms that the user really wants to exit the program
    print("You chose to exit the program")
    choice = input("Are you sure (Y/N)? ")

    if choice == 'y' or 'Y':
        fb = open('EMPDATA.txt', 'w')
        for i in lst:
            fb.close()
            print('Execution stopped!')
            sys.exit()
    else:
        print('Execution not stopped.')

# %%
def get_emp_input(): 
    emp_name = input('Enter the Employee Name: ')
    emp_address = input('Enter the City: ')

    return (emp_name, emp_city)

# %%
def get_department_input():
    dept_name = input('Enter the Department Name: ')
    location = input('Enter the Department Location: ')
    
    flag = True
    while flag:
        try:
            dept_number = int(input("Enter the Department Number: "))
        except ValueError:
            print('Enter a integer value for year.')
        else:
            flag = False

    return (dept_name, dept_number,location)

# %%
def get_fulltimeemployee_input():
    flag = True
    while flag:
        try:
            salary = float(input('Enter the salary: '))
        except ValueError:
            print('\nEnter a numerical value for salary!')
        else:
            flag = False
    return (salary)

# %%
def get_contractbasis_input():
    flag = True
    while flag:
        try:
            hoursWorked = int(input('Enter the hours worked: '))
        except ValueError:
            print('Enter a integer value for hours worked!')
        try:
            hourlyRate = float(input('Enter the hourly rate: '))
        except ValueError:
            print('Enter a numeric value for salary!')
        else:
            flag = False
        flag = True

    return (hoursWorked, hourlyRate)

# %%
def get_consultant_input():
    flag1 = True
    while flag1:
        
        try:
            hoursWorked = int(input('Enter the hours worked: '))
        except ValueError:
            print('Enter a integer value for hours worked!')
        else:
            flag1 = False
        flag1 = True
        
        flag2 = True
    while flag2:
        try:
            ProjectType = int(input('Enter the Project Type (1, 2 or 3): '))
            if(ProjectType < 1 or ProjectType > 3):
                raise Exception 
        except Exception:
            print('Wrong input of Project Type!')
        else:
            flag2 = False
        flag2 = True

    return (hoursWorked, ProjectType)

# %%
main()
